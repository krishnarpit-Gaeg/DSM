# %% [markdown]
# # Q1. Who developed Python Programming Language?

# %% [raw]
# Python Developed By Guido van Rossum in the late of 1980, and released in 1991

# %% [markdown]
# # Q2. Which type of Programming does Python support?

# %% [raw]
# Python supports object-oriented, structured, and functional programming

# %% [markdown]
# # Q3. Is Python case sensitive when dealing with identifiers?

# %% [raw]
# Yes, Python is case sensitive

# %% [markdown]
# # Q4. What is the correct extension of the Python file?

# %% [raw]
# The correct extension is .py.

# %% [markdown]
# # Q5. Is Python code compiled or interpreted?

# %% [raw]
# Python is an interpreted language.

# %% [markdown]
# # Q6. Name a few blocks of code used to define in Python language?

# %% [raw]
#  Examples: functions (def), classes (class), conditional blocks (if/elif/else), loops (for, while)

# %% [markdown]
# # Q7. State a character used to give single-line comments in Python?

# %% [raw]
#  The # symbol.

# %% [markdown]
# # Q8. Mention functions which can help us to find the version of python that we are currently working on?

# %% [raw]
# Use sys.version or platform.python_version().

# %% [markdown]
# # Q9. Python supports the creation of anonymous functions at runtime, using a construct called _ _ _ _ _ _ _

# %% [raw]
# lambda functions.

# %% [markdown]
# # Q10. What does pip stand for python?

# %% [raw]
#  Pip Installs Packages (or Pip Installs Python)

# %% [markdown]
# # Q11. Mention a few built-in functions in python?

# %% [raw]
# Examples: len(), type(), print(), input(), sum(), max(), min().

# %% [markdown]
# # Q12. What is the maximum possible length of an identifier in Python?

# %% [raw]
# There is no fixed limit; it depends on the system’s memory.

# %% [markdown]
# # Q13. What are the benefits of using Python?

# %% [raw]
# Easy to learn, readable syntax, large standard library, cross-platform, supports multiple paradigms, strong community support.

# %% [markdown]
# # Q14. How is memory managed in Python?

# %% [raw]
# Python uses automatic garbage collection and a private heap space managed by the interpreter.

# %% [markdown]
# # Q15. How to install Python on Windows and set path variables?

# %% [raw]
# 1. Download Python from the official site (python.org).
# 2. Run the installer and check “Add Python to PATH”.
# 3. Alternatively, set the PATH manually via System Properties → Environment Variables → Path.

# %% [markdown]
# # Q16. Is indentation required in python?

# %% [raw]
# Yes, indentation is mandatory in Python to define code blocks.
